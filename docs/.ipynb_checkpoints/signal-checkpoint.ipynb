# %%
# import all of the required libraries for the assignnement
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats  as stats
import math
import random

# %%
rad = np.array(list(range(1,365)))

# %%
rads = np.concatenate((rad,rad,rad,rad,rad))

# %%
rads = rads*2*math.pi/365

# %%
timeDays = np.array(list(range(1,len(rads)+1)))

# %%
sineWave = np.sin(dataSet[:,1])

# %%
plt.plot(timeDays,sineWave)

# %%
noise = np.random.normal(0, 0.2, len(rads))
sineWaveWithNoise = sineWave + noise

# %%
plt.plot(timeDays,sineWaveWithNoise)

# %%
speed = np.array([])

for i in range(2,len(sineWave)):
    
    actualSpeed = abs(sineWave[i] - sineWave[i-1])
    
    speed = np.append(speed,actualSpeed)

# %%
speed = [n for n in speed if n <= 0.0175]

# %%
plt.plot(speed)

# %%
len(speed)
# Out:
# 1814

# %%
acc = np.array([])

for j in range(len(speed)):
    
    actualAcc = abs(speed[j]-speed[j-1])
    
    acc = np.append(acc,actualAcc)

# %%
plt.plot(acc)
